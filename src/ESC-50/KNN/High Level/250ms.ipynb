# %%
import sys
sys.path.insert(0, '../../../')

import pandas as pd
from preprocess import Audio_Processor
from sklearn import metrics
from classification_plots import plot_confusion_matrix, plot_learning_curve
import matplotlib.pyplot as plt
import os
import numpy as np
from data_utils import enumerate_strings
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.pipeline import Pipeline
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/magenta/models/nsynth/wavenet/masked.py:115: UniformUnitScaling.__init__ (from tensorflow.python.ops.init_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.initializers.variance_scaling instead with distribution=uniform to get equivalent behavior.
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# Able to specify which GPU to use
os.environ["CUDA_VISIBLE_DEVICES"]="1"

SR = 16000
blocksize = int(SR/4)
overlap = int(SR/8)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Setup

# %%
path_to_db='../../../../ESC-50/'
ps = Audio_Processor(path_to_db + 'audio/', sr=SR)
dataset = pd.read_csv(path_to_db + 'meta/esc50.csv')
classes = [None] * 50
h_classes = ['Human & Animal', 'Interacting Materials']
mapping = {
    'dog': 0,
    'rooster': 0,
    'pig': 0,
    'cow': 0,
    'frog': 0,
    'cat': 0,
    'hen': 0,
    'insects': 0,
    'sheep': 0,
    'crow': 0,
    'rain': 1,
    'sea_waves': 1,
    'crackling_fire': 1,
    'crickets': 0,
    'chirping_birds': 0,
    'water_drops': 1,
    'wind': 1,
    'pouring_water': 1,
    'toilet_flush': 1,
    'thunderstorm': 1,
    'crying_baby': 0,
    'sneezing': 0,
    'clapping': 1,
    'breathing': 0,
    'coughing': 0,
    'footsteps': 1,
    'laughing': 0,
    'brushing_teeth': 1,
    'snoring': 0,
    'drinking_sipping': 1,
    'door_wood_knock': 1,
    'mouse_click': 1,
    'keyboard_typing': 1,
    'door_wood_creaks': 1,
    'can_opening': 1,
    'washing_machine': 1,
    'vacuum_cleaner': 1,
    'clock_alarm': 1,
    'clock_tick': 1,
    'glass_breaking':1,
    'helicopter': 1,
    'chainsaw': 1,
    'siren': 1,
    'car_horn': 1,
    'engine': 1,
    'train': 1,
    'church_bells': 1,
    'airplane': 1,
    'fireworks': 1,
    'hand_saw': 1,
}
dataset['h_target'] = None
for index, row in dataset.iterrows():
    target = row['target']
    classes[target] = row['category']
    dataset.loc[index, 'h_target'] = mapping[row['category']]

# %% [markdown]
# ## Getting Preprocessed Data
# We allow for previously preprocessed data to be retrieved for faster training turnaround. If the fold has been preprocessed, it is loaded but if not it is processed and saved.

# %%
df = ps.preprocess_fold(dataset, 
                        kind='mfcc', 
                        blocksize=blocksize, 
                        overlap=overlap,
                        folds=10,
                        random_state=42
                       )

# %%
df.describe()
# Out:
#         mfcc_2_std  mfcc_2_mean  mfcc_2_noise   mfcc_3_std  mfcc_3_mean  \
# count  2000.000000  2000.000000   2000.000000  2000.000000  2000.000000
# mean     72.864867    46.555438     39.303472    34.357633    31.580748
# std      20.686417    12.839961     12.632800    10.463501    10.494278
# min       1.023857     1.390291      2.463784     2.217799     1.468053
# 25%      58.401021    37.259355     29.535553    26.185062    23.092788
# 50%      72.067949    45.530706     37.705584    33.644909    30.861021
# 75%      86.848214    54.964281     47.292583    41.779940    39.835966
# max     210.860506    94.641428     87.565995    74.447375    67.522471
#
#        mfcc_3_noise   mfcc_4_std  mfcc_4_mean  mfcc_4_noise   mfcc_5_std  \
# count   2000.000000  2000.000000  2000.000000   2000.000000  2000.000000
# mean      31.534475    31.198025    31.341147     30.897054    30.280411
# std       10.720429    10.602236    11.118253     11.124000    10.783517
# min        2.356047     1.082973     0.667087      1.524121     1.350411
# 25%       22.500621    22.227644    22.170130     22.189913    21.535122
# 50%       31.213859    31.296936    31.504400     31.393603    31.241432
# 75%       39.837809    39.539145    39.920004     39.259747    38.505474
# max       72.120633    83.856240    92.764368    100.907831    98.163545
#
#          ...     sflat_noise    sroll_std   sroll_mean  sroll_noise  \
# count    ...     2000.000000  2000.000000  2000.000000  2000.000000
# mean     ...        0.007040     0.009648    13.515125    24.481013
# std      ...        0.158591     0.156010    11.572505    14.782931
# min      ...       -0.841209    -1.047266     6.145738    10.621702
# 25%      ...       -0.073462    -0.069485    10.483121    20.119718
# 50%      ...        0.009400     0.018312    12.590953    23.350114
# 75%      ...        0.090130     0.094727    15.309424    26.943112
# max      ...        0.708718     0.771758   500.861016   589.306962
#
#           rmse_std    rmse_mean   rmse_noise    h_target       target  \
# count  2000.000000  2000.000000  2000.000000  2000.00000  2000.000000
# mean      4.827707    22.530463     5.285919     0.64000    24.500000
# std       5.143978     8.605834     2.296010     0.48012    14.434479
# min       2.054451    10.441863     0.843697     0.00000     0.000000
# 25%       3.742620    17.424135     3.403414     0.00000    12.000000
# 50%       4.553567    20.781431     4.865013     1.00000    24.500000
# 75%       5.400495    25.663909     6.937377     1.00000    37.000000
# max     221.594445   235.207972    15.894835     1.00000    49.000000
#
#            fold
# count  2000.000
# mean      5.500
# std       2.873
# min       1.000
# 25%       3.000
# 50%       5.500
# 75%       8.000
# max      10.000
#
# [8 rows x 132 columns]

# %%
from sklearn.model_selection import train_test_split
train, test, = train_test_split(
                        df[df.fold != 1], test_size=0.20, random_state=42)

# %%
train_X = train.drop(['target', 'h_target', 'fold'], axis=1)
train_y = train['h_target']
test_X = test.drop(['target', 'h_target', 'fold'], axis=1)
test_y = test['h_target']

# %% [markdown]
# # Training

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_regression
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
train_X = scaler.fit_transform(train_X)
feat_red = PCA(n_components=30)
feat_red.fit(train_X,y=train_y)
train_X = feat_red.transform(train_X)

params = {
          'n_neighbors': range(5,25,1),
          'algorithm': ('ball_tree', 'kd_tree', 'brute')
         }

knn = KNN(n_neighbors=15, algorithm='ball_tree')

clf = GridSearchCV(knn, params, cv=5)

clf.fit(train_X, train_y)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=KNeighborsClassifier(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=15, p=2,
#            weights='uniform'),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'n_neighbors': range(5, 25), 'algorithm': ('ball_tree', 'kd_tree', 'brute')},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
pd.DataFrame(clf.cv_results_)
# Out:
#     mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 0        0.001399         0.021063         0.722917          0.799305
# 1        0.001513         0.012021         0.704167          0.798613
# 2        0.001301         0.012038         0.718056          0.779860
# 3        0.001326         0.012550         0.718750          0.782117
# 4        0.001538         0.015237         0.711111          0.765103
# 5        0.001525         0.014561         0.711111          0.772920
# 6        0.001871         0.021217         0.705556          0.754168
# 7        0.001229         0.011960         0.706944          0.759552
# 8        0.001419         0.013852         0.701389          0.744445
# 9        0.002169         0.032319         0.704167          0.751217
# 10       0.003990         0.026245         0.696528          0.737674
# 11       0.002383         0.031169         0.706250          0.743751
# 12       0.002133         0.028284         0.705556          0.735939
# 13       0.002108         0.036338         0.711111          0.739583
# 14       0.002062         0.032215         0.711111          0.733683
# 15       0.002056         0.034723         0.706944          0.736109
# 16       0.004155         0.042075         0.701389          0.729340
# 17       0.002004         0.042552         0.702083          0.732115
# 18       0.001657         0.024356         0.696528          0.723262
# 19       0.001408         0.013713         0.705556          0.727257
# 20       0.001427         0.010203         0.722917          0.799305
# 21       0.001421         0.010362         0.704167          0.798613
# 22       0.001375         0.010482         0.718056          0.779860
# 23       0.001245         0.010309         0.718750          0.782117
# 24       0.001259         0.010756         0.711111          0.765103
# 25       0.001227         0.010776         0.711111          0.772920
# 26       0.001231         0.010942         0.705556          0.754168
# 27       0.001210         0.010894         0.706944          0.759552
# 28       0.001210         0.011054         0.701389          0.744445
# 29       0.001685         0.014261         0.704167          0.751217
# 30       0.001484         0.013713         0.696528          0.737674
# 31       0.001451         0.013650         0.706250          0.743751
# 32       0.001261         0.012550         0.705556          0.735939
# 33       0.001930         0.019595         0.711111          0.739583
# 34       0.001523         0.015173         0.711111          0.733683
# 35       0.001743         0.018525         0.706944          0.736109
# 36       0.001540         0.015473         0.701389          0.729340
# 37       0.001334         0.013243         0.702083          0.732115
# 38       0.001190         0.012243         0.696528          0.723262
# 39       0.001172         0.012325         0.705556          0.727257
# 40       0.000853         0.007884         0.722917          0.799305
# 41       0.000905         0.007338         0.704167          0.798613
# 42       0.000907         0.007340         0.718056          0.779860
# 43       0.000908         0.008072         0.718750          0.782117
# 44       0.000922         0.007405         0.711111          0.765103
# 45       0.000918         0.007418         0.711111          0.772920
# 46       0.000908         0.007511         0.705556          0.754168
# 47       0.000927         0.007605         0.706944          0.759552
# 48       0.000921         0.007516         0.701389          0.744445
# 49       0.001114         0.046950         0.704167          0.751217
# 50       0.004631         0.033273         0.696528          0.737674
# 51       0.001136         0.019522         0.706250          0.743751
# 52       0.001135         0.018515         0.705556          0.735939
# 53       0.001126         0.020338         0.711111          0.739583
# 54       0.001178         0.012405         0.711111          0.733683
# 55       0.001085         0.013591         0.706944          0.736109
# 56       0.001115         0.027527         0.701389          0.729340
# 57       0.001122         0.015957         0.702083          0.732115
# 58       0.006412         0.032439         0.696528          0.723262
# 59       0.001480         0.031814         0.705556          0.727257
#
#    param_algorithm param_n_neighbors  \
# 0        ball_tree                 5
# 1        ball_tree                 6
# 2        ball_tree                 7
# 3        ball_tree                 8
# 4        ball_tree                 9
# 5        ball_tree                10
# 6        ball_tree                11
# 7        ball_tree                12
# 8        ball_tree                13
# 9        ball_tree                14
# 10       ball_tree                15
# 11       ball_tree                16
# 12       ball_tree                17
# 13       ball_tree                18
# 14       ball_tree                19
# 15       ball_tree                20
# 16       ball_tree                21
# 17       ball_tree                22
# 18       ball_tree                23
# 19       ball_tree                24
# 20         kd_tree                 5
# 21         kd_tree                 6
# 22         kd_tree                 7
# 23         kd_tree                 8
# 24         kd_tree                 9
# 25         kd_tree                10
# 26         kd_tree                11
# 27         kd_tree                12
# 28         kd_tree                13
# 29         kd_tree                14
# 30         kd_tree                15
# 31         kd_tree                16
# 32         kd_tree                17
# 33         kd_tree                18
# 34         kd_tree                19
# 35         kd_tree                20
# 36         kd_tree                21
# 37         kd_tree                22
# 38         kd_tree                23
# 39         kd_tree                24
# 40           brute                 5
# 41           brute                 6
# 42           brute                 7
# 43           brute                 8
# 44           brute                 9
# 45           brute                10
# 46           brute                11
# 47           brute                12
# 48           brute                13
# 49           brute                14
# 50           brute                15
# 51           brute                16
# 52           brute                17
# 53           brute                18
# 54           brute                19
# 55           brute                20
# 56           brute                21
# 57           brute                22
# 58           brute                23
# 59           brute                24
#
#                                            params  rank_test_score  \
# 0    {'n_neighbors': 5, 'algorithm': 'ball_tree'}                1
# 1    {'n_neighbors': 6, 'algorithm': 'ball_tree'}               40
# 2    {'n_neighbors': 7, 'algorithm': 'ball_tree'}                7
# 3    {'n_neighbors': 8, 'algorithm': 'ball_tree'}                4
# 4    {'n_neighbors': 9, 'algorithm': 'ball_tree'}               10
# 5   {'n_neighbors': 10, 'algorithm': 'ball_tree'}               10
# 6   {'n_neighbors': 11, 'algorithm': 'ball_tree'}               31
# 7   {'n_neighbors': 12, 'algorithm': 'ball_tree'}               22
# 8   {'n_neighbors': 13, 'algorithm': 'ball_tree'}               49
# 9   {'n_neighbors': 14, 'algorithm': 'ball_tree'}               40
# 10  {'n_neighbors': 15, 'algorithm': 'ball_tree'}               55
# 11  {'n_neighbors': 16, 'algorithm': 'ball_tree'}               28
# 12  {'n_neighbors': 17, 'algorithm': 'ball_tree'}               31
# 13  {'n_neighbors': 18, 'algorithm': 'ball_tree'}               10
# 14  {'n_neighbors': 19, 'algorithm': 'ball_tree'}               10
# 15  {'n_neighbors': 20, 'algorithm': 'ball_tree'}               22
# 16  {'n_neighbors': 21, 'algorithm': 'ball_tree'}               49
# 17  {'n_neighbors': 22, 'algorithm': 'ball_tree'}               46
# 18  {'n_neighbors': 23, 'algorithm': 'ball_tree'}               55
# 19  {'n_neighbors': 24, 'algorithm': 'ball_tree'}               31
# 20     {'n_neighbors': 5, 'algorithm': 'kd_tree'}                1
# 21     {'n_neighbors': 6, 'algorithm': 'kd_tree'}               40
# 22     {'n_neighbors': 7, 'algorithm': 'kd_tree'}                7
# 23     {'n_neighbors': 8, 'algorithm': 'kd_tree'}                4
# 24     {'n_neighbors': 9, 'algorithm': 'kd_tree'}               10
# 25    {'n_neighbors': 10, 'algorithm': 'kd_tree'}               10
# 26    {'n_neighbors': 11, 'algorithm': 'kd_tree'}               31
# 27    {'n_neighbors': 12, 'algorithm': 'kd_tree'}               22
# 28    {'n_neighbors': 13, 'algorithm': 'kd_tree'}               49
# 29    {'n_neighbors': 14, 'algorithm': 'kd_tree'}               40
# 30    {'n_neighbors': 15, 'algorithm': 'kd_tree'}               55
# 31    {'n_neighbors': 16, 'algorithm': 'kd_tree'}               28
# 32    {'n_neighbors': 17, 'algorithm': 'kd_tree'}               31
# 33    {'n_neighbors': 18, 'algorithm': 'kd_tree'}               10
# 34    {'n_neighbors': 19, 'algorithm': 'kd_tree'}               10
# 35    {'n_neighbors': 20, 'algorithm': 'kd_tree'}               22
# 36    {'n_neighbors': 21, 'algorithm': 'kd_tree'}               49
# 37    {'n_neighbors': 22, 'algorithm': 'kd_tree'}               46
# 38    {'n_neighbors': 23, 'algorithm': 'kd_tree'}               55
# 39    {'n_neighbors': 24, 'algorithm': 'kd_tree'}               31
# 40       {'n_neighbors': 5, 'algorithm': 'brute'}                1
# 41       {'n_neighbors': 6, 'algorithm': 'brute'}               40
# 42       {'n_neighbors': 7, 'algorithm': 'brute'}                7
# 43       {'n_neighbors': 8, 'algorithm': 'brute'}                4
# 44       {'n_neighbors': 9, 'algorithm': 'brute'}               10
# 45      {'n_neighbors': 10, 'algorithm': 'brute'}               10
# 46      {'n_neighbors': 11, 'algorithm': 'brute'}               31
# 47      {'n_neighbors': 12, 'algorithm': 'brute'}               22
# 48      {'n_neighbors': 13, 'algorithm': 'brute'}               49
# 49      {'n_neighbors': 14, 'algorithm': 'brute'}               40
# 50      {'n_neighbors': 15, 'algorithm': 'brute'}               55
# 51      {'n_neighbors': 16, 'algorithm': 'brute'}               28
# 52      {'n_neighbors': 17, 'algorithm': 'brute'}               31
# 53      {'n_neighbors': 18, 'algorithm': 'brute'}               10
# 54      {'n_neighbors': 19, 'algorithm': 'brute'}               10
# 55      {'n_neighbors': 20, 'algorithm': 'brute'}               22
# 56      {'n_neighbors': 21, 'algorithm': 'brute'}               49
# 57      {'n_neighbors': 22, 'algorithm': 'brute'}               46
# 58      {'n_neighbors': 23, 'algorithm': 'brute'}               55
# 59      {'n_neighbors': 24, 'algorithm': 'brute'}               31
#
#     split0_test_score  split0_train_score       ...         split2_test_score  \
# 0            0.692042            0.801043       ...                  0.760417
# 1            0.692042            0.812337       ...                  0.732639
# 2            0.705882            0.790617       ...                  0.760417
# 3            0.719723            0.795830       ...                  0.774306
# 4            0.698962            0.773241       ...                  0.746528
# 5            0.698962            0.789748       ...                  0.760417
# 6            0.685121            0.770634       ...                  0.743056
# 7            0.692042            0.773241       ...                  0.750000
# 8            0.698962            0.758471       ...                  0.729167
# 9            0.678201            0.767159       ...                  0.750000
# 10           0.671280            0.748045       ...                  0.732639
# 11           0.681661            0.752389       ...                  0.743056
# 12           0.688581            0.751520       ...                  0.732639
# 13           0.698962            0.752389       ...                  0.736111
# 14           0.698962            0.753258       ...                  0.746528
# 15           0.681661            0.748914       ...                  0.756944
# 16           0.695502            0.740226       ...                  0.739583
# 17           0.695502            0.737619       ...                  0.743056
# 18           0.705882            0.730669       ...                  0.725694
# 19           0.692042            0.735882       ...                  0.753472
# 20           0.692042            0.801043       ...                  0.760417
# 21           0.692042            0.812337       ...                  0.732639
# 22           0.705882            0.790617       ...                  0.760417
# 23           0.719723            0.795830       ...                  0.774306
# 24           0.698962            0.773241       ...                  0.746528
# 25           0.698962            0.789748       ...                  0.760417
# 26           0.685121            0.770634       ...                  0.743056
# 27           0.692042            0.773241       ...                  0.750000
# 28           0.698962            0.758471       ...                  0.729167
# 29           0.678201            0.767159       ...                  0.750000
# 30           0.671280            0.748045       ...                  0.732639
# 31           0.681661            0.752389       ...                  0.743056
# 32           0.688581            0.751520       ...                  0.732639
# 33           0.698962            0.752389       ...                  0.736111
# 34           0.698962            0.753258       ...                  0.746528
# 35           0.681661            0.748914       ...                  0.756944
# 36           0.695502            0.740226       ...                  0.739583
# 58           0.679443            0.718994      0.006690        0.013351
# 59           0.689895            0.723330      0.000552        0.015352
#
#     std_test_score  std_train_score
# 0         0.023067         0.004930
# 1         0.015260         0.008111
# 2         0.025451         0.009584
# 3         0.032430         0.013407
# 4         0.022590         0.009055
# 5         0.030037         0.008992
# 6         0.021821         0.009792
# 7         0.023241         0.009975
# 8         0.015994         0.009206
# 9         0.024486         0.009309
# 10        0.022539         0.007495
# 11        0.024092         0.006433
# 12        0.014577         0.011454
# 13        0.015331         0.009619
# 14        0.018091         0.011568
# 15        0.027193         0.010301
# 16        0.019207         0.008539
# 17        0.021533         0.007973
# 18        0.017553         0.008373
# 19        0.024145         0.006657
# 20        0.023067         0.004930
# 21        0.015260         0.008111
# 22        0.025451         0.009584
# 23        0.032430         0.013407
# 24        0.022590         0.009055
# 25        0.030037         0.008992
# 26        0.021821         0.009792
# 27        0.023241         0.009975
# 28        0.015994         0.009206
# 29        0.024486         0.009309
# 30        0.022539         0.007495
# 31        0.024092         0.006433
# 32        0.014577         0.011454
# 33        0.015331         0.009619
# 34        0.018091         0.011568
# 35        0.027193         0.010301
# 36        0.019207         0.008539
# 37        0.021533         0.007973
# 38        0.017553         0.008373
# 39        0.024145         0.006657
# 40        0.023067         0.004930
# 41        0.015260         0.008111
# 42        0.025451         0.009584
# 43        0.032430         0.013407
# 44        0.022590         0.009055
# 45        0.030037         0.008992
# 46        0.021821         0.009792
# 47        0.023241         0.009975
# 48        0.015994         0.009206
# 49        0.024486         0.009309
# 50        0.022539         0.007495
# 51        0.024092         0.006433
# 52        0.014577         0.011454
# 53        0.015331         0.009619
# 54        0.018091         0.011568
# 55        0.027193         0.010301
# 56        0.019207         0.008539
# 57        0.021533         0.007973
# 58        0.017553         0.008373
# 59        0.024145         0.006657
#
# [60 rows x 22 columns]

# %%
test_X = scaler.transform(test_X)
test_X = feat_red.transform(test_X)
pred = clf.predict(test_X)
print(metrics.accuracy_score(test_y, pred))
cm = metrics.confusion_matrix(test_y, pred)
plt.figure(figsize=(10,10))
plot_confusion_matrix(cm, h_classes)
plt.show()
# Out:
# 0.7027777777777777
# Confusion matrix, without normalization
# [[ 53  86]
#  [ 21 200]]

# %% [markdown]
# # All Data

# %%
all_df = df[df.fold == 1]

# %%
all_df.head()
# Out:
#     mfcc_2_std  mfcc_2_mean  mfcc_2_noise  mfcc_3_std  mfcc_3_mean  \
# 29   92.424748    59.141242     36.846606   20.968241    15.579660
# 49   80.026334    43.699629     33.855491   26.743481    29.245538
# 56   85.975483    70.241904     68.170603   58.295780    51.781578
# 65  110.385284    61.793937     52.698346   47.364183    46.379313
# 69   70.094849    35.303785     37.217964   40.640240    32.847498
#
#     mfcc_3_noise  mfcc_4_std  mfcc_4_mean  mfcc_4_noise  mfcc_5_std  ...   \
# 29     15.751939   15.863563    14.673644     13.023693   10.921275  ...
# 49     31.119842   25.972480    25.312478     25.158757   22.965982  ...
# 56     50.067378   52.207571    49.074085     45.277827   44.449342  ...
# 65     46.856578   46.282778    46.638665     43.544902   44.590495  ...
# 69     28.306000   34.013978    37.584400     35.427584   38.294607  ...
#
#     sflat_noise  sroll_std  sroll_mean  sroll_noise  rmse_std  rmse_mean  \
# 29     0.080787  -0.115509   18.608194    36.212375  6.859917  33.937771
# 49     0.006161   0.251638   13.626741    18.341014  4.690726  17.136722
# 56     0.127927   0.069146   12.966969    18.934236  5.272783  17.825757
# 65    -0.002064   0.067368   10.146723    17.343412  4.264112  14.344427
# 69     0.082853   0.128150   12.071106    23.774442  3.617514  20.146890
#
#     rmse_noise  h_target  target  fold
# 29    7.555853         0       8     1
# 49   11.156650         0       3     1
# 56    6.032061         1      40     1
# 65    4.929389         1      12     1
# 69    3.616052         0       4     1
#
# [5 rows x 132 columns]

# %%
X = all_df.drop(['target', 'h_target', 'fold'], axis=1)
y = all_df['h_target']
X = scaler.transform(X)
X = feat_red.transform(X)

# %%
pred = clf.predict(X)
pred_prob = clf.predict_proba(X)
print(metrics.accuracy_score(y, pred))
cm = metrics.confusion_matrix(y, pred)
plt.figure(figsize=(10,10))
plot_confusion_matrix(cm, h_classes)
plt.show()
# Out:
# 0.73
# Confusion matrix, without normalization
# [[ 26  43]
#  [ 11 120]]

# %%
clf.best_estimator_
# Out:
# KNeighborsClassifier(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
import seaborn as sns
misclassified = {
    'Actual h_target': [],
    'Actual target': [],
    'Anim_prob': [],
    'Interact_prob': []
}
for row, p, prob, Y in zip(all_df.iterrows(), pred, pred_prob, y):
    Y = int(Y)
    p = int(p)
    if p!=Y:
        misclassified['Actual target'].append(classes[int(row[1]['target'])])
        misclassified['Actual h_target'].append(h_classes[p])
        misclassified['Anim_prob'].append(prob[0])
        misclassified['Interact_prob'].append(prob[1])

misclassified = pd.DataFrame.from_dict(misclassified)
misclassified.head()
# Out:
#          Actual h_target     Actual target  Anim_prob  Interact_prob
# 0  Interacting Materials             sheep        0.4            0.6
# 1  Interacting Materials              frog        0.2            0.8
# 2  Interacting Materials               pig        0.2            0.8
# 3  Interacting Materials               cat        0.0            1.0
# 4         Human & Animal  door_wood_creaks        1.0            0.0

# %%
average_prob = misclassified.groupby('Actual h_target').mean()
average_prob.head()
# Out:
#                        Anim_prob  Interact_prob
# Actual h_target
# Human & Animal          0.654545       0.345455
# Interacting Materials   0.223256       0.776744

# %%
average_prob = misclassified.groupby('Actual target').mean()
average_prob
# Out:
#                   Anim_prob  Interact_prob
# Actual target
# breathing          0.400000       0.600000
# can_opening        0.600000       0.400000
# cat                0.200000       0.800000
# chirping_birds     0.160000       0.840000
# clapping           0.600000       0.400000
# clock_tick         0.800000       0.200000
# coughing           0.000000       1.000000
# cow                0.266667       0.733333
# crackling_fire     0.600000       0.400000
# crickets           0.240000       0.760000
# crying_baby        0.400000       0.600000
# door_wood_creaks   0.733333       0.266667
# frog               0.240000       0.760000
# hand_saw           0.600000       0.400000
# hen                0.100000       0.900000
# insects            0.300000       0.700000
# laughing           0.300000       0.700000
# pig                0.200000       0.800000
# pouring_water      0.600000       0.400000
# sheep              0.250000       0.750000
# siren              0.600000       0.400000
# sneezing           0.200000       0.800000
# snoring            0.000000       1.000000
# wind               0.600000       0.400000

# %%
from matplotlib import pyplot as plt
fig, ax = plt.subplots(figsize=(50,10))
sns.countplot(x='Actual target', hue='Actual h_target',data=misclassified)
