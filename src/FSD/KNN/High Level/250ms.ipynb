# %%
import sys
sys.path.insert(0, '../../../')

import pandas as pd
from preprocess import Audio_Processor
from sklearn import metrics
from classification_plots import plot_confusion_matrix, plot_learning_curve
import matplotlib.pyplot as plt
import os
import numpy as np
from data_utils import enumerate_strings
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.pipeline import Pipeline
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/magenta/models/nsynth/wavenet/masked.py:115: UniformUnitScaling.__init__ (from tensorflow.python.ops.init_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.initializers.variance_scaling instead with distribution=uniform to get equivalent behavior.
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# Able to specify which GPU to use
os.environ["CUDA_VISIBLE_DEVICES"]="1"

SR = 16000
blocksize = int(SR/4)
overlap = int(SR/8)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Setup

# %%
path_to_db = '../../../../../data/FSDKaggle2018/'
dataset = pd.read_csv(path_to_db + 'meta/train.csv')
dataset = dataset.drop(['manually_verified', 'freesound_id', 'license'], axis=1)
ps = Audio_Processor(path_to_db + 'train/')
classes = dataset.label.unique()
h_classes = ['Human & Animal', 'Interacting Materials', 'Musical Instruments']
mapping = {'Hi-hat': h_classes[2],
           'Saxophone': h_classes[2],
           'Trumpet': h_classes[2],
           'Glockenspiel': h_classes[2],
           'Cello': h_classes[2],
           'Knock': h_classes[1],
           'Gunshot_or_gunfire': h_classes[1],
           'Clarinet': h_classes[2],
           'Computer_keyboard': h_classes[1],
           'Keys_jangling': h_classes[1],
           'Snare_drum': h_classes[2],
           'Writing': h_classes[1],
           'Laughter': h_classes[0],
           'Tearing': h_classes[1],
           'Fart': h_classes[1],
           'Oboe': h_classes[2],
           'Flute': h_classes[2],
           'Cough': h_classes[0],
           'Telephone': h_classes[1],
           'Bark': h_classes[0],
           'Chime': h_classes[2],
           'Bass_drum': h_classes[2],
           'Bus': h_classes[1],
           'Squeak': h_classes[0],
           'Scissors': h_classes[1],
           'Harmonica': h_classes[2],
           'Gong': h_classes[2],
           'Microwave_oven': h_classes[1],
           'Burping_or_eructation': h_classes[0],
           'Double_bass': h_classes[2],
           'Shatter': h_classes[1],
           'Fireworks': h_classes[1],
           'Tambourine': h_classes[2],
           'Cowbell': h_classes[2],
           'Electric_piano': h_classes[2],
           'Meow': h_classes[0],
           'Drawer_open_or_close': h_classes[1],
           'Applause': h_classes[1],
           'Acoustic_guitar': h_classes[2],
           'Violin_or_fiddle': h_classes[2],
           'Finger_snapping': h_classes[1]
           }
dataset['h_target'] = None
for index, row in dataset.iterrows():
    row['target'] = np.where(classes == row['label'])
    dataset.loc[index, 'h_target'] = mapping[row['label']]
dataset.columns = ['filename', 'target', 'h_target']
enum_map = enumerate_strings(dataset, ['filename'])

# %% [markdown]
# ## Getting Preprocessed Data
# We allow for previously preprocessed data to be retrieved for faster training turnaround. If the fold has been preprocessed, it is loaded but if not it is processed and saved.

# %%
df = ps.preprocess_fold(dataset, 
                        kind='mfcc', 
                        blocksize=blocksize, 
                        overlap=overlap,
                        folds=10,
                        random_state=42
                       )

# %%
df.describe()
# Out:
#         mfcc_2_std  mfcc_2_mean  mfcc_2_noise   mfcc_3_std  mfcc_3_mean  \
# count  9473.000000  9473.000000   9473.000000  9473.000000  9473.000000
# mean     66.240346    40.575210     33.252812    28.589215    25.966119
# std      22.969282    13.340798     11.352381     9.462242     8.970966
# min       0.598030     0.901494      0.307574     0.244798     0.461283
# 25%      50.895061    31.484456     25.585518    21.936827    19.620470
# 50%      64.216342    38.893866     31.662855    27.409678    24.665538
# 75%      80.407794    48.512334     39.205680    34.116788    31.390975
# max     214.188325   119.282059    120.341853   116.269968    88.865159
#
#        mfcc_3_noise   mfcc_4_std  mfcc_4_mean  mfcc_4_noise   mfcc_5_std  \
# count   9473.000000  9473.000000  9473.000000   9473.000000  9473.000000
# mean      25.483509    25.085997    25.158320     25.039126    24.686638
# std        9.270678     9.260134     9.767039      9.859174     9.812604
# min        0.434550     0.178663     0.198955      0.174059     0.103143
# 25%       18.749731    18.149932    17.629885     17.392083    16.971175
# 50%       24.073793    23.721216    23.820657     23.753736    23.620308
# 75%       31.287458    31.167012    31.461855     31.529744    31.314564
# max       78.757534    72.751514    83.612219     83.173143    89.160821
#
#           ...       sflat_noise    sroll_std   sroll_mean  sroll_noise  \
# count     ...       9473.000000  9473.000000  9473.000000  9473.000000
# mean      ...         -0.012041    -0.020632    14.015522    26.469842
# std       ...          0.290511     0.294412    13.843881    23.251890
# min       ...         -2.516879    -2.060510     4.663059     8.465304
# 25%       ...         -0.130413    -0.134236    10.534396    20.691696
# 50%       ...          0.000962     0.001564    12.827961    24.823127
# 75%       ...          0.120285     0.114644    15.923647    29.644201
# max       ...          1.715085     2.481905  1157.838236  1996.988483
#
#            rmse_std    rmse_mean   rmse_noise     h_target       target  \
# count   9473.000000  9473.000000  9473.000000  9473.000000  9473.000000
# mean       9.204595    23.810951     4.396655     1.356804    20.385728
# std      428.647657    10.255413     9.774938     0.731472    12.262045
# min        1.723963     6.434500     0.785033     0.000000     0.000000
# 25%        3.406220    17.680320     2.682849     1.000000    10.000000
# 50%        4.446506    21.656005     3.809612     2.000000    20.000000
# 75%        5.580331    27.308570     5.423217     2.000000    32.000000
# max    41723.231189   287.008264   932.273164     2.000000    40.000000
#
#               fold
# count  9473.000000
# mean      5.498892
# std       2.872690
# min       1.000000
# 25%       3.000000
# 50%       5.000000
# 75%       8.000000
# max      10.000000
#
# [8 rows x 132 columns]

# %%
from sklearn.model_selection import train_test_split
train, test, = train_test_split(
                        df[df.fold != 1], test_size=0.20, random_state=42)

# %%
train_X = train.drop(['target', 'h_target', 'fold'], axis=1)
train_y = train['h_target']
test_X = test.drop(['target', 'h_target', 'fold'], axis=1)
test_y = test['h_target']

# %% [markdown]
# # Training

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_regression
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
train_X = scaler.fit_transform(train_X)
feat_red = PCA(n_components=30)
feat_red.fit(train_X,y=train_y)
train_X = feat_red.transform(train_X)

params = {
          'n_neighbors': range(5,25,1),
          'algorithm': ('ball_tree', 'kd_tree', 'brute')
         }

knn = KNN(n_neighbors=15, algorithm='ball_tree')

clf = GridSearchCV(knn, params, cv=5)

clf.fit(train_X, train_y)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=KNeighborsClassifier(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=15, p=2,
#            weights='uniform'),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'n_neighbors': range(5, 25), 'algorithm': ('ball_tree', 'kd_tree', 'brute')},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
pd.DataFrame(clf.cv_results_)
# Out:
#     mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 0        0
# 4        ball_tree                 9
# 5        ball_tree                10
# 6        ball_tree                11
# 7        ball_tree                12
# 8        ball_tree                13
# 9        ball_tree                14
# 10       ball_tree                15
# 11       ball_tree                16
# 12       ball_tree                17
# 13       ball_tree                18
# 14       ball_tree                19
# 15       ball_tree                20
# 16       ball_tree                21
# 17       ball_tree                22
# 18       ball_tree                23
# 19       ball_tree                24
# 20         kd_tree                 5
# 21         kd_tree                 6
# 22         kd_tree                 7
# 23         kd_tree                 8
# 24         kd_tree                 9
# 25         kd_tree                10
# 26         kd_tree                11
# 27         kd_tree                12
# 28         kd_tree                13
# 29         kd_tree                14
# 30         kd_tree                15
# 31         kd_tree                16
# 32         kd_tree                17
# 33         kd_tree                18
# 34         kd_tree                19
# 35         kd_tree                20
# 36         kd_tree                21
# 37         kd_tree                22
# 38         kd_tree                23
# 39         kd_tree                24
# 40           brute                 5
# 41           brute                 6
# 42           brute                 7
# 43           brute                 8
# 44           brute                 9
# 45           brute                10
# 46           brute                11
# 47           brute                12
# 48           brute                13
# 49           brute                14
# 50           brute                15
# 51           brute                16
# 52           brute                17
# 53           brute                18
# 54           brute                19
# 55           brute                20
# 56           brute                21
# 57           brute                22
# 58           brute                23
# 59           brute                24
#
#                                            params  rank_test_score  \
# 0    {'n_neighbors': 5, 'algorithm': 'ball_tree'}               43
# 1    {'n_neighbors': 6, 'algorithm': 'ball_tree'}               31
# 2    {'n_neighbors': 7, 'algorithm': 'ball_tree'}               37
# 3    {'n_neighbors': 8, 'algorithm': 'ball_tree'}                4
# 4    {'n_neighbors': 9, 'algorithm': 'ball_tree'}                1
# 5   {'n_neighbors': 10, 'algorithm': 'ball_tree'}               16
# 6   {'n_neighbors': 11, 'algorithm': 'ball_tree'}               40
# 7   {'n_neighbors': 12, 'algorithm': 'ball_tree'}               34
# 8   {'n_neighbors': 13, 'algorithm': 'ball_tree'}                7
# 9   {'n_neighbors': 14, 'algorithm': 'ball_tree'}               10
# 10  {'n_neighbors': 15, 'algorithm': 'ball_tree'}               10
# 11  {'n_neighbors': 16, 'algorithm': 'ball_tree'}               25
# 12  {'n_neighbors': 17, 'algorithm': 'ball_tree'}               16
# 13  {'n_neighbors': 18, 'algorithm': 'ball_tree'}               16
# 14  {'n_neighbors': 19, 'algorithm': 'ball_tree'}               25
# 15  {'n_neighbors': 20, 'algorithm': 'ball_tree'}               46
# 16  {'n_neighbors': 21, 'algorithm': 'ball_tree'}               49
# 17  {'n_neighbors': 22, 'algorithm': 'ball_tree'}               52
# 18  {'n_neighbors': 23, 'algorithm': 'ball_tree'}               55
# 19  {'n_neighbors': 24, 'algorithm': 'ball_tree'}               58
# 20     {'n_neighbors': 5, 'algorithm': 'kd_tree'}               43
# 21     {'n_neighbors': 6, 'algorithm': 'kd_tree'}               31
# 22     {'n_neighbors': 7, 'algorithm': 'kd_tree'}               37
# 23     {'n_neighbors': 8, 'algorithm': 'kd_tree'}                4
# 24     {'n_neighbors': 9, 'algorithm': 'kd_tree'}                1
# 25    {'n_neighbors': 10, 'algorithm': 'kd_tree'}               16
# 26    {'n_neighbors': 11, 'algorithm': 'kd_tree'}               40
# 27    {'n_neighbors': 12, 'algorithm': 'kd_tree'}               34
# 28    {'n_neighbors': 13, 'algorithm': 'kd_tree'}                7
# 29    {'n_neighbors': 14, 'algorithm': 'kd_tree'}               10
# 30    {'n_neighbors': 15, 'algorithm': 'kd_tree'}               10
# 31    {'n_neighbors': 16, 'algorithm': 'kd_tree'}               25
# 32    {'n_neighbors': 17, 'algorithm': 'kd_tree'}               16
# 33    {'n_neighbors': 18, 'algorithm': 'kd_tree'}               16
# 34    {'n_neighbors': 19, 'algorithm': 'kd_tree'}               25
# 35    {'n_neighbors': 20, 'algorithm': 'kd_tree'}               46
# 36    {'n_neighbors': 21, 'algorithm': 'kd_tree'}               49
# 37    {'n_neighbors': 22, 'algorithm': 'kd_tree'}               52
# 38    {'n_neighbors': 23, 'algorithm': 'kd_tree'}               55
# 39    {'n_neighbors': 24, 'algorithm': 'kd_tree'}               58
# 40       {'n_neighbors': 5, 'algorithm': 'brute'}               43
# 41       {'n_neighbors': 6, 'algorithm': 'brute'}               31
# 42       {'n_neighbors': 7, 'algorithm': 'brute'}               37
# 43       {'n_neighbors': 8, 'algorithm': 'brute'}                4
# 44       {'n_neighbors': 9, 'algorithm': 'brute'}                1
# 45      {'n_neighbors': 10, 'algorithm': 'brute'}               16
# 46      {'n_neighbors': 11, 'algorithm': 'brute'}               40
# 47      {'n_neighbors': 12, 'algorithm': 'brute'}               34
# 48      {'n_neighbors': 13, 'algorithm': 'brute'}                7
# 49      {'n_neighbors': 14, 'algorithm': 'brute'}               10
# 50      {'n_neighbors': 15, 'algorithm': 'brute'}               10
# 51      {'n_neighbors': 16, 'algorithm': 'brute'}               25
# 52      {'n_neighbors': 17, 'algorithm': 'brute'}               16
# 53      {'n_neighbors': 18, 'algorithm': 'brute'}               16
# 54      {'n_neighbors': 19, 'algorithm': 'brute'}               25
# 55      {'n_neighbors': 20, 'algorithm': 'brute'}               46
# 56      {'n_neighbors': 21, 'algorithm': 'brute'}               49
# 57      {'n_neighbors': 22, 'algorithm': 'brute'}               52
# 58      {'n_neighbors': 23, 'algorithm': 'brute'}               55
# 59      {'n_neighbors': 24, 'algorithm': 'brute'}               58
#
#     split0_test_score  split0_train_score       ...         split2_test_score  \
# 0            0.703297            0.786068       ...                  0.715018
# 1            0.704029            0.772319       ...                  0.727473
# 2            0.714286            0.770119       ...                  0.711355
# 3            0.712088            0.764070       ...                  0.720147
# 4            0.709158            0.761137       ...                  0.722344
# 5            0.701832            0.754537       ...                  0.717216
# 6            0.705495            0.748304       ...                  0.717216
# 7            0.696703            0.745738       ...                  0.721612
# 8            0.701832            0.742071       ...                  0.723810
# 9            0.698901            0.742255       ...                  0.721612
# 10           0.701832            0.736389       ...                  0.714286
# 11           0.695971            0.735289       ...                  0.715018
# 12           0.696703            0.735289       ...                  0.710623
# 31           0.705580            0.733602      0.000050        0.002444
# 32           0.714391            0.729938      0.000175        0.007710
# 33           0.710720            0.731953      0.000285        0.006218
# 34           0.710720            0.726640      0.000060        0.002249
# 35           0.706314            0.728838      0.000062        0.003497
# 36           0.708517            0.727006      0.000073        0.002585
# 37           0.706314            0.725724      0.000051        0.002638
# 38           0.705580            0.722243      0.000064        0.002530
# 39           0.700441            0.718212      0.000141        0.002499
# 40           0.709251            0.788750      0.000186        0.028058
# 41           0.707048            0.775376      0.000007        0.010601
# 42           0.712922            0.768413      0.000007        0.006517
# 43           0.713656            0.765848      0.000035        0.008497
# 44           0.723201            0.761268      0.000024        0.007846
# 45           0.707783            0.753023      0.000229        0.007334
# 46           0.709251            0.748076      0.000047        0.005923
# 47           0.709251            0.744229      0.000025        0.033794
# 48           0.714391            0.740198      0.000302        0.050922
# 49           0.709251            0.738182      0.000009        0.005555
# 50           0.708517            0.735434      0.000169        0.004474
# 51           0.705580            0.733602      0.000079        0.006160
# 52           0.714391            0.729938      0.000022        0.006009
# 53           0.710720            0.731953      0.000061        0.014837
# 54           0.710720            0.726640      0.000179        0.010351
# 55           0.706314            0.728838      0.000805        0.026246
# 56           0.708517            0.727006      0.000208        0.011948
# 57           0.706314            0.725724      0.000060        0.005188
# 58           0.705580            0.722243      0.000013        0.005545
# 59           0.700441            0.718212      0.000017        0.016521
#
#     std_test_score  std_train_score
# 0         0.008017         0.001989
# 1         0.011103         0.003772
# 2         0.008651         0.002745
# 3         0.007405         0.002452
# 4         0.010190         0.001588
# 5         0.006442         0.002186
# 6         0.007294         0.001369
# 7         0.008502         0.001601
# 8         0.010514         0.001983
# 9         0.008100         0.001948
# 10        0.005745         0.001828
# 11        0.006304         0.002298
# 12        0.006207         0.002263
# 13        0.006269         0.002877
# 14        0.004142         0.002215
# 15        0.003813         0.002357
# 16        0.006857         0.002122
# 17        0.005152         0.001613
# 18        0.004629         0.002096
# 19        0.003299         0.001022
# 20        0.008017         0.001989
# 21        0.011103         0.003772
# 22        0.008651         0.002745
# 23        0.007405         0.002452
# 24        0.010190         0.001588
# 25        0.006442         0.002186
# 26        0.007294         0.001369
# 27        0.008502         0.001601
# 28        0.010514         0.001983
# 29        0.008100         0.001948
# 30        0.005745         0.001828
# 31        0.006304         0.002298
# 32        0.006207         0.002263
# 33        0.006269         0.002877
# 34        0.004142         0.002215
# 35        0.003813         0.002357
# 36        0.006857         0.002122
# 37        0.005152         0.001613
# 38        0.004629         0.002096
# 39        0.003299         0.001022
# 40        0.008017         0.001989
# 41        0.011103         0.003772
# 42        0.008651         0.002745
# 43        0.007405         0.002452
# 44        0.010190         0.001588
# 45        0.006442         0.002186
# 46        0.007294         0.001369
# 47        0.008502         0.001601
# 48        0.010514         0.001983
# 49        0.008100         0.001948
# 50        0.005745         0.001828
# 51        0.006304         0.002298
# 52        0.006207         0.002263
# 53        0.006269         0.002877
# 54        0.004142         0.002215
# 55        0.003813         0.002357
# 56        0.006857         0.002122
# 57        0.005152         0.001613
# 58        0.004629         0.002096
# 59        0.003299         0.001022
#
# [60 rows x 22 columns]

# %%
test_X = scaler.transform(test_X)
test_X = feat_red.transform(test_X)
pred = clf.predict(test_X)
print(metrics.accuracy_score(test_y, pred))
cm = metrics.confusion_matrix(test_y, pred)
plt.figure(figsize=(10,10))
plot_confusion_matrix(cm, h_classes)
plt.show()
# Out:
# 0.6950146627565983
# Confusion matrix, without normalization
# [[ 85 127  41]
#  [ 51 464  70]
#  [ 50 181 636]]

# %% [markdown]
# # All Data

# %%
all_df = df[df.fold == 1]

# %%
all_df.head()
# Out:
#     mfcc_2_std  mfcc_2_mean  mfcc_2_noise  mfcc_3_std  mfcc_3_mean  \
# 3    54.657463    22.403386     20.374281   14.934783    17.264752
# 10   30.879524    31.470498     23.012898   29.810553    23.651823
# 14   99.742400    58.232331     51.266784   43.676831    38.188466
# 19  108.890889    53.493131     39.001484   27.536289    22.475096
# 29   74.361393    50.888222     40.118562   38.071880    40.014431
#
#     mfcc_3_noise  mfcc_4_std  mfcc_4_mean  mfcc_4_noise  mfcc_5_std  ...   \
# 3      30.158590   18.415202    13.052059     20.633322   13.515480  ...
# 10     26.041291   37.503051    29.627941     28.171450   39.205779  ...
# 14     37.023362   33.898922    35.534931     34.553768   36.325718  ...
# 19     18.785693   19.027203    22.575981     17.676037   16.870288  ...
# 29     41.045089   35.067856    35.323970     31.772201   37.995677  ...
#
#     sflat_noise  sroll_std  sroll_mean  sroll_noise  rmse_std  rmse_mean  \
# 3     -1.112581  -0.756274   15.604813    44.222322  5.416419  34.568492
# 10     0.117783  -0.140268   20.979961    30.238074  3.342199  32.775020
# 14    -0.031171  -0.094132   12.841130    19.602180  4.487939  16.499150
# 19    -0.078297  -0.040533    7.648848    15.962555  3.164979  14.499246
# 29     0.219566  -0.009561   12.876941    22.397775  4.833818  19.983807
#
#     rmse_noise  h_target  target  fold
# 3     6.441344         2      19     1
# 10    3.351956         2      23     1
# 14    5.296138         2       6     1
# 19    2.527786         0      26     1
# 29    6.515273         2       7     1
#
# [5 rows x 132 columns]

# %%
X = all_df.drop(['target', 'h_target', 'fold'], axis=1)
y = all_df['h_target']
X = scaler.transform(X)
X = feat_red.transform(X)

# %%
pred = clf.predict(X)
pred_prob = clf.predict_proba(X)
print(metrics.accuracy_score(y, pred))
cm = metrics.confusion_matrix(y, pred)
plt.figure(figsize=(10,10))
plot_confusion_matrix(cm, h_classes)
plt.show()
# Out:
# 0.7088607594936709
# Confusion matrix, without normalization
# [[ 50  65  20]
#  [ 27 269  40]
#  [ 31  93 353]]

# %%
clf.best_estimator_
# Out:
# KNeighborsClassifier(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=9, p=2,
#            weights='uniform')

# %%
import seaborn as sns
misclassified = {
    'Actual h_target': [],
    'Actual target': [],
    'Anim_prob': [],
    'Interact_prob': [],
    'Music_prob': []
}
for row, p, prob, Y in zip(all_df.iterrows(), pred, pred_prob, y):
    Y = int(Y)
    p = int(p)
    if p!=Y:
        misclassified['Actual target'].append(classes[int(row[1]['target'])])
        misclassified['Actual h_target'].append(h_classes[p])
        misclassified['Anim_prob'].append(prob[0])
        misclassified['Interact_prob'].append(prob[1])
        misclassified['Music_prob'].append(prob[2])

misclassified = pd.DataFrame.from_dict(misclassified)
misclassified.head()
# Out:
#          Actual h_target          Actual target  Anim_prob  Interact_prob  \
# 0  Interacting Materials                   Gong   0.222222       0.777778
# 1  Interacting Materials                 Squeak   0.222222       0.666667
# 2    Musical Instruments  Burping_or_eructation   0.000000       0.333333
# 3    Musical Instruments                  Cough   0.222222       0.111111
# 4  Interacting Materials        Acoustic_guitar   0.333333       0.555556
#
#    Music_prob
# 0    0.000000
# 1    0.111111
# 2    0.666667
# 3    0.666667
# 4    0.111111

# %%
average_prob = misclassified.groupby('Actual h_target').mean()
average_prob.head()
# Out:
#                        Anim_prob  Interact_prob  Music_prob
# Actual h_target
# Human & Animal          0.542146       0.291188    0.166667
# Interacting Materials   0.142053       0.684248    0.173699
# Musical Instruments     0.131481       0.200000    0.668519

# %%
average_prob = misclassified.groupby('Actual target').mean()
average_prob
# Out:
#                        Anim_prob  Interact_prob  Music_prob
# Actual target
# Acoustic_guitar         0.325397       0.515873    0.158730
# Applause                0.166667       0.211111    0.622222
# Bass_drum               0.266667       0.288889    0.444444
# Burping_or_eructation   0.407407       0.240741    0.351852
# Bus                     0.305556       0.513889    0.180556
# Cello                   0.215686       0.607843    0.176471
# Chime                   0.242424       0.595960    0.161616
# Clarinet                0.155556       0.577778    0.266667
# Computer_keyboard       0.000000       0.555556    0.444444
# Cough                   0.263889       0.277778    0.458333
# Cowbell                 0.198413       0.603175    0.198413
# Double_bass             0.444444       0.444444    0.111111
# Drawer_open_or_close    0.407407       0.296296    0.296296
# Electric_piano          0.131944       0.597222    0.270833
# Fart                    0.055556       0.500000    0.444444
# Finger_snapping         0.388889       0.222222    0.388889
# Fireworks               0.277778       0.388889    0.333333
# Flute                   0.055556       0.333333    0.611111
# Glockenspiel            0.088889       0.588889    0.322222
# Gong                    0.164021       0.613757    0.222222
# Gunshot_or_gunfire      0.000000       0.555556    0.444444
# Harmonica               0.126984       0.222222    0.650794
# Hi-hat                  0.185185       0.481481    0.333333
# Knock                   0.000000       0.444444    0.555556
# Laughter                0.296296       0.481481    0.222222
# Meow                    0.151515       0.676768    0.171717
# Microwave_oven          0.111111       0.396825    0.492063
# Oboe                    0.269841       0.253968    0.476190
# Saxophone               0.388889       0.388889    0.222222
# Scissors                0.555556       0.444444    0.000000
# Shatter                 0.444444       0.222222    0.333333
# Snare_drum              0.238095       0.595238    0.166667
# Squeak                  0.154321       0.617284    0.228395
# Tambourine              0.539683       0.253968    0.206349
# Tearing                 0.666667       0.277778    0.055556
# Telephone               0.296296       0.370370    0.333333
# Trumpet                 0.177778       0.477778    0.344444
# Violin_or_fiddle        0.209877       0.543210    0.246914
# Writing                 0.222222       0.648148    0.129630

# %%
from matplotlib import pyplot as plt
fig, ax = plt.subplots(figsize=(50,10))
sns.countplot(x='Actual target', hue='Actual h_target',data=misclassified)
